# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Importing the dataset

# %%
df = pd.read_csv("/kaggle/input/used-cars-price-prediction/train-data.csv")
df.head()
# Out:
#    Unnamed: 0                              Name    Location  Year  \
# 0           0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1           1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2           2                      Honda Jazz V     Chennai  2011
# 3           3                 Maruti Ertiga VDI     Chennai  2012
# 4           4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998 CC
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199 CC
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 4              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
#
#        Power  Seats  New_Price  Price
# 0  58.16 bhp    5.0        NaN   1.75
# 1  126.2 bhp    5.0        NaN  12.50
# 2   88.7 bhp    5.0  8.61 Lakh   4.50
# 3  88.76 bhp    7.0        NaN   6.00
# 4  140.8 bhp    5.0        NaN  17.74

# %%
testdf = pd.read_csv("/kaggle/input/used-cars-price-prediction/test-data.csv")
testdf.head()
# Out:
#    Unnamed: 0                                       Name    Location  Year  \
# 0           0                    Maruti Alto K10 LXI CNG       Delhi  2014
# 1           1              Maruti Alto 800 2016-2019 LXI  Coimbatore  2013
# 2           2  Toyota Innova Crysta Touring Sport 2.4 MT      Mumbai  2017
# 3           3                       Toyota Etios Liva GD   Hyderabad  2012
# 4           4                          Hyundai i20 Magna      Mumbai  2014
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type      Mileage   Engine  \
# 0              40929       CNG       Manual      First  32.26 km/kg   998 CC
# 1              54493    Petrol       Manual     Second    24.7 kmpl   796 CC
# 2              34000    Diesel       Manual      First   13.68 kmpl  2393 CC
# 3             139000    Diesel       Manual      First   23.59 kmpl  1364 CC
# 4              29000    Petrol       Manual      First    18.5 kmpl  1197 CC
#
#        Power  Seats   New_Price
# 0   58.2 bhp    4.0         NaN
# 1   47.3 bhp    5.0         NaN
# 2  147.8 bhp    7.0  25.27 Lakh
# 3   null bhp    5.0         NaN
# 4  82.85 bhp    5.0         NaN

# %%
df = df.drop("Unnamed: 0", axis=1)
testdf = testdf.drop("Unnamed: 0", axis=1)

# %%
df.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price
# 0        NaN   1.75
# 1        NaN  12.50
# 2  8.61 Lakh   4.50
# 3        NaN   6.00
# 4        NaN  17.74

# %%
testdf.head()
# Out:
#                                         Name    Location  Year  \
# 0                    Maruti Alto K10 LXI CNG       Delhi  2014
# 1              Maruti Alto 800 2016-2019 LXI  Coimbatore  2013
# 2  Toyota Innova Crysta Touring Sport 2.4 MT      Mumbai  2017
# 3                       Toyota Etios Liva GD   Hyderabad  2012
# 4                          Hyundai i20 Magna      Mumbai  2014
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type      Mileage   Engine  \
# 0              40929       CNG       Manual      First  32.26 km/kg   998 CC
# 1              54493    Petrol       Manual     Second    24.7 kmpl   796 CC
# 2              34000    Diesel       Manual      First   13.68 kmpl  2393 CC
# 3             139000    Diesel       Manual      First   23.59 kmpl  1364 CC
# 4              29000    Petrol       Manual      First    18.5 kmpl  1197 CC
#
#        Power  Seats   New_Price
# 0   58.2 bhp    4.0         NaN
# 1   47.3 bhp    5.0         NaN
# 2  147.8 bhp    7.0  25.27 Lakh
# 3   null bhp    5.0         NaN
# 4  82.85 bhp    5.0         NaN

# %%
df.isnull().sum()
# Out:
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 36
# Power                  36
# Seats                  42
# New_Price            5195
# Price                   0
# dtype: int64

# %%
df.shape
# Out:
# (6019, 13)

# %%
testdf.isnull().sum()
# Out:
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 0
# Engine                 10
# Power                  10
# Seats                  11
# New_Price            1052
# dtype: int64

# %%
testdf.shape
# Out:
# (1234, 12)

# %%
df = df.dropna(how='any')
testdf = testdf.dropna(how='any')

# %%
df.shape
# Out:
# (823, 13)

# %%
testdf.shape
# Out:
# (182, 12)

# %%
df.head()
# Out:
#                                  Name Location  Year  Kilometers_Driven  \
# 2                        Honda Jazz V  Chennai  2011              46000
# 7   Toyota Innova Crysta 2.8 GX AT 8S   Mumbai  2016              36000
# 10                   Maruti Ciaz Zeta    Kochi  2018              25692
# 15        Mitsubishi Pajero Sport 4X4    Delhi  2014             110000
# 20                  BMW 3 Series 320d    Kochi  2014              32982
#
#    Fuel_Type Transmission Owner_Type     Mileage   Engine       Power  Seats  \
# 2     Petrol       Manual      First   18.2 kmpl  1199 CC    88.7 bhp    5.0
# 7     Diesel    Automatic      First  11.36 kmpl  2755 CC   171.5 bhp    8.0
# 10    Petrol       Manual      First  21.56 kmpl  1462 CC  103.25 bhp    5.0
# 15    Diesel       Manual      First   13.5 kmpl  2477 CC  175.56 bhp    7.0
# 20    Diesel    Automatic      First  22.69 kmpl  1995 CC     190 bhp    5.0
#
#      New_Price  Price
# 2    8.61 Lakh   4.50
# 7      21 Lakh  17.50
# 10  10.65 Lakh   9.95
# 15  32.01 Lakh  15.00
# 20  47.87 Lakh  18.55

# %%
testdf.head()
# Out:
#                                          Name Location  Year  \
# 2   Toyota Innova Crysta Touring Sport 2.4 MT   Mumbai  2017
# 30                 Toyota Etios Cross 1.4L VD  Chennai  2014
# 36               Skoda Rapid 1.6 MPI AT Style   Mumbai  2017
# 39              BMW 5 Series 520d Luxury Line   Mumbai  2012
# 43               Skoda Rapid 1.6 MPI Ambition   Jaipur  2018
#
#     Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 2               34000    Diesel       Manual      First  13.68 kmpl  2393 CC
# 30              70000    Diesel       Manual     Second  23.59 kmpl  1364 CC
# 36              13500    Petrol    Automatic      First  14.84 kmpl  1598 CC
# 39              66889    Diesel    Automatic      First  22.48 kmpl  1995 CC
# 43               4000    Petrol       Manual      First  15.41 kmpl  1598 CC
#
#          Power  Seats   New_Price
# 2    147.8 bhp    7.0  25.27 Lakh
# 30   67.06 bhp    5.0   9.27 Lakh
# 36  103.52 bhp    5.0  14.95 Lakh
# 39     190 bhp    5.0  70.43 Lakh
# 43  103.52 bhp    5.0  11.89 Lakh

# %%
df = df.drop('New_Price', axis=1)
testdf = testdf.drop('New_Price', axis=1)

# %%
df.head()
# Out:
#                                  Name Location  Year  Kilometers_Driven  \
# 2                        Honda Jazz V  Chennai  2011              46000
# 7   Toyota Innova Crysta 2.8 GX AT 8S   Mumbai  2016              36000
# 10                   Maruti Ciaz Zeta    Kochi  2018              25692
# 15        Mitsubishi Pajero Sport 4X4    Delhi  2014             110000
# 20                  BMW 3 Series 320d    Kochi  2014              32982
#
#    Fuel_Type Transmission Owner_Type     Mileage   Engine       Power  Seats  \
# 2     Petrol       Manual      First   18.2 kmpl  1199 CC    88.7 bhp    5.0
# 7     Diesel    Automatic      First  11.36 kmpl  2755 CC   171.5 bhp    8.0
# 10    Petrol       Manual      First  21.56 kmpl  1462 CC  103.25 bhp    5.0
# 15    Diesel       Manual      First   13.5 kmpl  2477 CC  175.56 bhp    7.0
# 20    Diesel    Automatic      First  22.69 kmpl  1995 CC     190 bhp    5.0
#
#     Price
# 2    4.50
# 7   17.50
# 10   9.95
# 15  15.00
# 20  18.55

# %%
testdf.head()
# Out:
#                                          Name Location  Year  \
# 2   Toyota Innova Crysta Touring Sport 2.4 MT   Mumbai  2017
# 30                 Toyota Etios Cross 1.4L VD  Chennai  2014
# 36               Skoda Rapid 1.6 MPI AT Style   Mumbai  2017
# 39              BMW 5 Series 520d Luxury Line   Mumbai  2012
# 43               Skoda Rapid 1.6 MPI Ambition   Jaipur  2018
#
#     Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 2               34000    Diesel       Manual      First  13.68 kmpl  2393 CC
# 30              70000    Diesel       Manual     Second  23.59 kmpl  1364 CC
# 36              13500    Petrol    Automatic      First  14.84 kmpl  1598 CC
# 39              66889    Diesel    Automatic      First  22.48 kmpl  1995 CC
# 43               4000    Petrol       Manual      First  15.41 kmpl  1598 CC
#
#          Power  Seats
# 2    147.8 bhp    7.0
# 30   67.06 bhp    5.0
# 36  103.52 bhp    5.0
# 39     190 bhp    5.0
# 43  103.52 bhp    5.0

# %%
trainlist = df['Name']
testlist = testdf['Name']
print(f"Missing Values{set(testlist).difference(trainlist)}")
# Out:
# Missing Values{'Mahindra Verito Vibe 1.5 dCi D6', 'Mahindra KUV 100 G80 K4 Plus 5Str', 'BMW 7 Series 730Ld DPE Signature', 'Hyundai Creta 1.6 SX Automatic', 'Fiat Punto EVO 1.3 Emotion', 'Skoda Rapid 1.5 TDI AT Ambition', 'Skoda Rapid 1.6 MPI AT Style', 'Maruti Alto LXI', 'Honda Jazz VX CVT', 'Mahindra KUV 100 D75 K8 5Str', 'Mercedes-Benz GLA Class 220 d 4MATIC', 'Ford Freestyle Titanium Plus Diesel', 'Fiat Avventura Urban Cross 1.3 Multijet Emotion', 'Hyundai Elite i20 Magna Plus', 'Bentley Flying Spur W12', 'Hyundai Tucson 2.0 e-VGT 4WD AT GLS', 'Mercedes-Benz B Class B180 Sport', 'Honda BR-V i-VTEC VX MT', 'Jeep Compass 1.4 Sport', 'Hyundai Creta 1.6 SX Diesel', 'Tata Tiago AMT 1.2 Revotron XTA', 'Maruti Celerio X VXI Option', 'Renault Duster 85PS Diesel RxZ', 'Maruti Vitara Brezza ZDi Plus AMT', 'Maruti Ertiga VXI Petrol', 'Honda BR-V i-DTEC S MT', 'Honda BRV i-DTEC V MT', 'Toyota Etios Liva 1.4 VXD', 'Jaguar XF 2.0 Petrol Portfolio', 'Mahindra Bolero Power Plus ZLX', 'Maruti Ignis 1.2 AMT Delta', 'Skoda Octavia 2.0 TDI MT Style', 'Fiat Linea Classic 1.3 Multijet', 'Toyota Innova Crysta Touring Sport 2.4 MT', 'Volkswagen Vento 1.6 Trendline', 'Mitsubishi Pajero Sport 4X2 AT', 'Hyundai Xcent 1.2 CRDi SX', 'Hyundai i20 Active SX Diesel', 'Volkswagen Vento 1.5 TDI Highline Plus AT', 'Mahindra Bolero SLX', 'Ford EcoSport 1.5 Petrol Ambiente', 'Toyota Etios Cross 1.2L G', 'Datsun GO T Petrol', 'Tata Tiago 1.05 Revotorq XT Option', 'Maruti Wagon R VXI AMT Opt', 'Maruti Vitara Brezza ZDi AMT', 'Honda WRV i-DTEC VX', 'BMW 5 Series 530i Sport Line'}

# %%
df['Cars'] = df['Name'].apply(lambda x: x.split(" ")[0]) + ' ' + df['Name'].apply(lambda x: x.split(" ")[1])
testdf['Cars'] = testdf['Name'].apply(lambda x: x.split(" ")[0]) + ' ' + testdf['Name'].apply(lambda x: x.split(" ")[1])

# %%
df.head()
# Out:
#                                  Name Location  Year  Kilometers_Driven  \
# 2                        Honda Jazz V  Chennai  2011              46000
# 7   Toyota Innova Crysta 2.8 GX AT 8S   Mumbai  2016              36000
# 10                   Maruti Ciaz Zeta    Kochi  2018              25692
# 15        Mitsubishi Pajero Sport 4X4    Delhi  2014             110000
# 20                  BMW 3 Series 320d    Kochi  2014              32982
#
#    Fuel_Type Transmission Owner_Type     Mileage   Engine       Power  Seats  \
# 2     Petrol       Manual      First   18.2 kmpl  1199 CC    88.7 bhp    5.0
# 7     Diesel    Automatic      First  11.36 kmpl  2755 CC   171.5 bhp    8.0
# 10    Petrol       Manual      First  21.56 kmpl  1462 CC  103.25 bhp    5.0
# 15    Diesel       Manual      First   13.5 kmpl  2477 CC  175.56 bhp    7.0
# 20    Diesel    Automatic      First  22.69 kmpl  1995 CC     190 bhp    5.0
#
#     Price               Cars
# 2    4.50         Honda Jazz
# 7   17.50      Toyota Innova
# 10   9.95        Maruti Ciaz
# 15  15.00  Mitsubishi Pajero
# 20  18.55              BMW 3

# %%
set(testdf['Cars']).issubset(set(df['Cars']))
# Out:
# False

# %%
trainlist = df['Cars']
testlist = testdf['Cars']
print(f"Missing Values{set(testlist).difference(trainlist)}")
# Out:
# Missing Values{'Fiat Punto', 'Mercedes-Benz B', 'Fiat Avventura', 'Bentley Flying'}

# %%
testdf.drop(testdf[testdf['Cars'].isin(['OpelCorsa 1.4Gsi', 'Hindustan Motors', 'Bentley Flying', 'Nissan 370Z', 'Toyota Land', 'Fiat Abarth', 'Isuzu MU'])].index, inplace = True)

# %%
testdf.shape
# Out:
# (181, 12)

# %%
df.dtypes
# Out:
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage               object
# Engine                object
# Power                 object
# Seats                float64
# Price                float64
# Cars                  object
# dtype: object

# %%
df.head()
# Out:
#                                  Name Location  Year  Kilometers_Driven  \
# 2                        Honda Jazz V  Chennai  2011              46000
# 7   Toyota Innova Crysta 2.8 GX AT 8S   Mumbai  2016              36000
# 10                   Maruti Ciaz Zeta    Kochi  2018              25692
# 15        Mitsubishi Pajero Sport 4X4    Delhi  2014             110000
# 20                  BMW 3 Series 320d    Kochi  2014              32982
#
#    Fuel_Type Transmission Owner_Type     Mileage   Engine       Power  Seats  \
# 2     Petrol       Manual      First   18.2 kmpl  1199 CC    88.7 bhp    5.0
# 7     Diesel    Automatic      First  11.36 kmpl  2755 CC   171.5 bhp    8.0
# 10    Petrol       Manual      First  21.56 kmpl  1462 CC  103.25 bhp    5.0
# 15    Diesel       Manual      First   13.5 kmpl  2477 CC  175.56 bhp    7.0
# 20    Diesel    Automatic      First  22.69 kmpl  1995 CC     190 bhp    5.0
#
#     Price               Cars
# 2    4.50         Honda Jazz
# 7   17.50      Toyota Innova
# 10   9.95        Maruti Ciaz
# 15  15.00  Mitsubishi Pajero
# 20  18.55              BMW 3

# %%
testdf.head()
# Out:
#                                          Name Location  Year  \
# 2   Toyota Innova Crysta Touring Sport 2.4 MT   Mumbai  2017
# 30                 Toyota Etios Cross 1.4L VD  Chennai  2014
# 36               Skoda Rapid 1.6 MPI AT Style   Mumbai  2017
# 39              BMW 5 Series 520d Luxury Line   Mumbai  2012
# 43               Skoda Rapid 1.6 MPI Ambition   Jaipur  2018
#
#     Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 2               34000    Diesel       Manual      First  13.68 kmpl  2393 CC
# 30              70000    Diesel       Manual     Second  23.59 kmpl  1364 CC
# 36              13500    Petrol    Automatic      First  14.84 kmpl  1598 CC
# 39              66889    Diesel    Automatic      First  22.48 kmpl  1995 CC
# 43               4000    Petrol       Manual      First  15.41 kmpl  1598 CC
#
#          Power  Seats           Cars
# 2    147.8 bhp    7.0  Toyota Innova
# 30   67.06 bhp    5.0   Toyota Etios
# 36  103.52 bhp    5.0    Skoda Rapid
# 39     190 bhp    5.0          BMW 5
# 43  103.52 bhp    5.0    Skoda Rapid

# %%
testdf.describe()
# Out:
#               Year  Kilometers_Driven       Seats
# count   181.000000         181.000000  181.000000
# mean   2015.983425       38813.513812    5.270718
# std       2.090920       26985.335951    0.794896
# min    2010.000000        1000.000000    2.000000
# 25%    2015.000000       19764.000000    5.000000
# 50%    2017.000000       32352.000000    5.000000
# 75%    2017.000000       57200.000000    5.000000
# max    2019.000000      160000.000000    8.000000

# %%
df['Mileage'] = df['Mileage'].str.replace(' kmpl', '')
df['Power'] = df['Power'].str.replace('null bhp', '113')
df['Power'] = df['Power'].str.replace(' bhp', '')
df['Engine'] = df['Engine'].str.replace(' CC', '')
df['Mileage'] = df['Mileage'].str.replace(' km/kg', '')

# %%
testdf['Mileage'] = testdf['Mileage'].str.replace(' kmpl', '')
testdf['Power'] = testdf['Power'].str.replace('null bhp', '113')
testdf['Power'] = testdf['Power'].str.replace(' bhp', '')
testdf['Engine'] = testdf['Engine'].str.replace(' CC', '')
testdf['Mileage'] = testdf['Mileage'].str.replace(' km/kg', '')

# %%
df.query('Power == "147.8"')
# Out:
#                                    Name    Location  Year  Kilometers_Driven  \
# 60    Toyota Innova Crysta 2.4 GX MT 8S      Mumbai  2017              22000
# 256      Toyota Innova Crysta 2.4 ZX MT        Pune  2017              43000
# 298      Toyota Innova Crysta 2.4 ZX MT     Chennai  2016              48000
# 615   Toyota Innova Crysta 2.4 GX MT 8S   Hyderabad  2017              52000
# 697      Toyota Innova Crysta 2.4 ZX MT   Bangalore  2017              64798
# 850      Toyota Innova Crysta 2.4 ZX MT        Pune  2017              43200
# 952      Toyota Innova Crysta 2.4 ZX MT  Coimbatore  2018              92056
# 1012     Toyota Innova Crysta 2.4 GX MT     Chennai  2017              67489
# 1197     Toyota Innova Crysta 2.4 VX MT   Hyderabad  2017              24393
# 1427     Toyota Innova Crysta 2.4 VX MT       Kochi  2018               8899
# 1532  Toyota Innova Crysta 2.4 VX MT 8S  Coimbatore  2019              11241
# 2008     Toyota Innova Crysta 2.4 VX MT   Hyderabad  2017              67000
# 2030     Toyota Innova Crysta 2.4 VX MT      Mumbai  2016              25121
# 2763  Toyota Innova Crysta 2.4 VX MT 8S  Coimbatore  2017              72202
# 2920     Toyota Innova Crysta 2.4 VX MT      Mumbai  2017              38000
# 3555     Toyota Innova Crysta 2.4 VX MT  Coimbatore  2019              33598
# 4350  Toyota Innova Crysta 2.4 VX MT 8S  Coimbatore  2019              31271
# 4373     Toyota Innova Crysta 2.4 ZX MT   Ahmedabad  2016              54000
# 5366     Toyota Innova Crysta 2.4 GX MT   Hyderabad  2016              73000
# 5757     Toyota Innova Crysta 2.4 VX MT     Kolkata  2017              31000
#
#      Fuel_Type Transmission Owner_Type Mileage Engine  Power  Seats  Price  \
# 60      Diesel       Manual      First   13.68   2393  147.8    8.0  16.50
# 256     Diesel       Manual      First   13.68   2393  147.8    7.0  18.65
# 298     Diesel       Manual      First   13.68   2393  147.8    7.0  20.25
# 615     Diesel       Manual      First   13.68   2393  147.8    8.0  17.50
# 697     Diesel       Manual      First   13.68   2393  147.8    7.0  18.75
# 850     Diesel       Manual      First   13.68   2393  147.8    7.0  18.60
# 952     Diesel       Manual      First   13.68   2393  147.8    7.0  18.39
# 1012    Diesel       Manual      First   13.68   2393  147.8    7.0  16.50
# 1197    Diesel       Manual      First   13.68   2393  147.8    7.0  20.40
# 1427    Diesel       Manual      First   13.68   2393  147.8    7.0  19.92
# 1532    Diesel       Manual      First   13.68   2393  147.8    8.0  22.55
# 2008    Diesel       Manual      First   13.68   2393  147.8    7.0  16.50
# 2030    Diesel       Manual      First   13.68   2393  147.8    7.0  17.11
# 2763    Diesel       Manual      First   13.68   2393  147.8    8.0  17.92
# 2920    Diesel       Manual      First   13.68   2393  147.8    7.0  17.65
# 3555    Diesel       Manual      First   13.68   2393  147.8    7.0  22.20
# 4350    Diesel       Manual      First   13.68   2393  147.8    8.0  21.42
# 4373    Diesel       Manual      First   13.68   2393  147.8    7.0  16.50
# 5366    Diesel       Manual      First   13.68   2393  147.8    7.0  16.50
# 5757    Diesel       Manual      First   13.68   2393  147.8    7.0  16.95
#
#                Cars
# 60    Toyota Innova
# 256   Toyota Innova
# 298   Toyota Innova
# 615   Toyota Innova
# 697   Toyota Innova
# 850   Toyota Innova
# 952   Toyota Innova
# 1012  Toyota Innova
# 1197  Toyota Innova
# 1427  Toyota Innova
# 1532  Toyota Innova
# 2008  Toyota Innova
# 2030  Toyota Innova
# 2763  Toyota Innova
# 2920  Toyota Innova
# 3555  Toyota Innova
# 4350  Toyota Innova
# 4373  Toyota Innova
# 5366  Toyota Innova
# 5757  Toyota Innova

# %%
df.head()
# Out:
#                                  Name Location  Year  Kilometers_Driven  \
# 2                        Honda Jazz V  Chennai  2011              46000
# 7   Toyota Innova Crysta 2.8 GX AT 8S   Mumbai  2016              36000
# 10                   Maruti Ciaz Zeta    Kochi  2018              25692
# 15        Mitsubishi Pajero Sport 4X4    Delhi  2014             110000
# 20                  BMW 3 Series 320d    Kochi  2014              32982
#
#    Fuel_Type Transmission Owner_Type Mileage Engine   Power  Seats  Price  \
# 2     Petrol       Manual      First    18.2   1199    88.7    5.0   4.50
# 7     Diesel    Automatic      First   11.36   2755   171.5    8.0  17.50
# 10    Petrol       Manual      First   21.56   1462  103.25    5.0   9.95
# 15    Diesel       Manual      First    13.5   2477  175.56    7.0  15.00
# 20    Diesel    Automatic      First   22.69   1995     190    5.0  18.55
#
#                  Cars
# 2          Honda Jazz
# 7       Toyota Innova
# 10        Maruti Ciaz
# 15  Mitsubishi Pajero
# 20              BMW 3

# %%
#Converting all the object data types to Numerical whichever is feasible in df database
df['Mileage'] = pd.to_numeric(df['Power'])
df['Engine'] = pd.to_numeric(df['Engine'])
df['Power'] = pd.to_numeric(df['Power'])
df.dtypes
# Out:
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage              float64
# Engine                 int64
# Power                float64
# Seats                float64
# Price                float64
# Cars                  object
# dtype: object

# %%
testdf.head()
# Out:
#                                          Name Location  Year  \
# 2   Toyota Innova Crysta Touring Sport 2.4 MT   Mumbai  2017
# 30                 Toyota Etios Cross 1.4L VD  Chennai  2014
# 36               Skoda Rapid 1.6 MPI AT Style   Mumbai  2017
# 39              BMW 5 Series 520d Luxury Line   Mumbai  2012
# 43               Skoda Rapid 1.6 MPI Ambition   Jaipur  2018
#
#     Kilometers_Driven Fuel_Type Transmission Owner_Type Mileage Engine  \
# 2               34000    Diesel       Manual      First   13.68   2393
# 30              70000    Diesel       Manual     Second   23.59   1364
# 36              13500    Petrol    Automatic      First   14.84   1598
# 39              66889    Diesel    Automatic      First   22.48   1995
# 43               4000    Petrol       Manual      First   15.41   1598
#
#      Power  Seats           Cars
# 2    147.8    7.0  Toyota Innova
# 30   67.06    5.0   Toyota Etios
# 36  103.52    5.0    Skoda Rapid
# 39     190    5.0          BMW 5
# 43  103.52    5.0    Skoda Rapid

# %%
#Converting all the object data types to Numerical whichever is feasible in testdf database
testdf['Mileage'] = pd.to_numeric(testdf['Mileage'])
testdf['Engine'] = pd.to_numeric(testdf['Engine'])
testdf['Power'] = pd.to_numeric(testdf['Power'])
testdf.dtypes
# Out:
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage              float64
# Engine                 int64
# Power                float64
# Seats                float64
# Cars                  object
# dtype: object

# %%
df.describe()
# Out:
#               Year  Kilometers_Driven     Mileage       Engine       Power  \
# count   823.000000         823.000000  823.000000   823.000000  823.000000
# mean   2015.869988       40498.402187  120.227995  1615.489672  120.227995
# std       2.378709       28791.171759   55.623259   562.811691   55.623259
# min    2001.000000         600.000000   53.000000   799.000000   53.000000
# 25%    2015.000000       20487.500000   81.860000  1197.000000   81.860000
# 50%    2016.000000       34895.000000   99.000000  1497.000000   99.000000
# 75%    2017.000000       53829.000000  166.850000  1995.000000  166.850000
# max    2019.000000      215000.000000  444.000000  4951.000000  444.000000
#
#             Seats       Price
# count  823.000000  823.000000
# mean     5.304982   13.647606
# std      0.795707   14.860539
# min      2.000000    0.700000
# 25%      5.000000    5.000000
# 50%      5.000000    8.200000
# 75%      5.000000   17.500000
# max      8.000000  160.000000

# %%
df.isnull().sum()
# Out:
# Name                 0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Price                0
# Cars                 0
# dtype: int64

# %%
testdf.isnull().sum()
# Out:
# Name                 0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Cars                 0
# dtype: int64

# %%
feat1 = ['Cars', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type', 'Transmission', 'Mileage', 'Owner_Type', 'Engine', 'Power', 'Seats', 'Price']
df = pd.DataFrame(df, columns=feat1)

feat2 = ['Cars', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type', 'Transmission', 'Mileage', 'Owner_Type', 'Engine', 'Power', 'Seats']
testdf = pd.DataFrame(testdf, columns=feat2)

# %%
df = df.reset_index()
testdf = testdf.reset_index()
df
# Out:
#      index               Cars Location  Year  Kilometers_Driven Fuel_Type  \
# 0        2         Honda Jazz  Chennai  2011              46000    Petrol
# 1        7      Toyota Innova   Mumbai  2016              36000    Diesel
# 2       10        Maruti Ciaz    Kochi  2018              25692    Petrol
# 3       15  Mitsubishi Pajero    Delhi  2014             110000    Diesel
# 4       20              BMW 3    Kochi  2014              32982    Diesel
# ..     ...                ...      ...   ...                ...       ...
# 818   5999          Tata Bolt  Chennai  2016              10000    Petrol
# 819   6002   Volkswagen Vento   Mumbai  2011              38000    Petrol
# 820   6005      Maruti Vitara     Pune  2016              37208    Diesel
# 821   6010         Honda Brio    Delhi  2013              33746    Petrol
# 822   6014       Maruti Swift    Delhi  2014              27365    Diesel
#
#     Transmission  Mileage Owner_Type  Engine   Power  Seats  Price
# 0         Manual    88.70      First    1199   88.70    5.0   4.50
# 1      Automatic   171.50      First    2755  171.50    8.0  17.50
# 2         Manual   103.25      First    1462  103.25    5.0   9.95
# 3         Manual   175.56      First    2477  175.56    7.0  15.00
# 4      Automatic   190.00      First    1995  190.00    5.0  18.55
# ..           ...      ...        ...     ...     ...    ...    ...
# 818       Manual    88.70      First    1193   88.70    5.0   4.00
# 819       Manual   103.50      First    1598  103.50    5.0   3.25
# 820       Manual    88.50      First    1248   88.50    5.0   7.43
# 821       Manual    86.80      First    1198   86.80    5.0   3.20
# 822       Manual    74.00      First    1248   74.00    5.0   4.75
#
# [823 rows x 13 columns]

# %%
df = df.drop('index', axis=1)
testdf = testdf.drop('index', axis=1)

# %%
df.head()
# Out:
#                 Cars Location  Year  Kilometers_Driven Fuel_Type Transmission  \
# 0         Honda Jazz  Chennai  2011              46000    Petrol       Manual
# 1      Toyota Innova   Mumbai  2016              36000    Diesel    Automatic
# 2        Maruti Ciaz    Kochi  2018              25692    Petrol       Manual
# 3  Mitsubishi Pajero    Delhi  2014             110000    Diesel       Manual
# 4              BMW 3    Kochi  2014              32982    Diesel    Automatic
#
#    Mileage Owner_Type  Engine   Power  Seats  Price
# 0    88.70      First    1199   88.70    5.0   4.50
# 1   171.50      First    2755  171.50    8.0  17.50
# 2   103.25      First    1462  103.25    5.0   9.95
# 3   175.56      First    2477  175.56    7.0  15.00
# 4   190.00      First    1995  190.00    5.0  18.55

# %%
testdf.head()
# Out:
#             Cars Location  Year  Kilometers_Driven Fuel_Type Transmission  \
# 0  Toyota Innova   Mumbai  2017              34000    Diesel       Manual
# 1   Toyota Etios  Chennai  2014              70000    Diesel       Manual
# 2    Skoda Rapid   Mumbai  2017              13500    Petrol    Automatic
# 3          BMW 5   Mumbai  2012              66889    Diesel    Automatic
# 4    Skoda Rapid   Jaipur  2018               4000    Petrol       Manual
#
#    Mileage Owner_Type  Engine   Power  Seats
# 0    13.68      First    2393  147.80    7.0
# 1    23.59     Second    1364   67.06    5.0
# 2    14.84      First    1598  103.52    5.0
# 3    22.48      First    1995  190.00    5.0
# 4    15.41      First    1598  103.52    5.0

# %%
df = df.drop('Mileage', axis=1)
testdf = testdf.drop('Mileage', axis=1)

# %%
df.head()
# Out:
#                 Cars Location  Year  Kilometers_Driven Fuel_Type Transmission  \
# 0         Honda Jazz  Chennai  2011              46000    Petrol       Manual
# 1      Toyota Innova   Mumbai  2016              36000    Diesel    Automatic
# 2        Maruti Ciaz    Kochi  2018              25692    Petrol       Manual
# 3  Mitsubishi Pajero    Delhi  2014             110000    Diesel       Manual
# 4              BMW 3    Kochi  2014              32982    Diesel    Automatic
#
#   Owner_Type  Engine   Power  Seats  Price
# 0      First    1199   88.70    5.0   4.50
# 1      First    2755  171.50    8.0  17.50
# 2      First    1462  103.25    5.0   9.95
# 3      First    2477  175.56    7.0  15.00
# 4      First    1995  190.00    5.0  18.55

# %%
testdf.head()
# Out:
#             Cars Location  Year  Kilometers_Driven Fuel_Type Transmission  \
# 0  Toyota Innova   Mumbai  2017              34000    Diesel       Manual
# 1   Toyota Etios  Chennai  2014              70000    Diesel       Manual
# 2    Skoda Rapid   Mumbai  2017              13500    Petrol    Automatic
# 3          BMW 5   Mumbai  2012              66889    Diesel    Automatic
# 4    Skoda Rapid   Jaipur  2018               4000    Petrol       Manual
#
#   Owner_Type  Engine   Power  Seats
# 0      First    2393  147.80    7.0
# 1     Second    1364   67.06    5.0
# 2      First    1598  103.52    5.0
# 3      First    1995  190.00    5.0
# 4      First    1598  103.52    5.0

# %% [markdown]
# # Exploratory Data Analysis

# %%
# graph - No of petrol cars and diesel cars
# graph - kilometers, cars and price

# %%
#Comparison of Petrol to Diesel Cars
x = df.groupby('Fuel_Type').sum().index
y = df.groupby('Fuel_Type')['Cars'].count()

# %%
plt.bar(x, y)
plt.xlabel('Fuel Type')
plt.ylabel('Number')
plt.show()

# %%
print("Find most important features relative to Price-target")
numeric_vals = df.select_dtypes(include=['number'])
numeric_corr = numeric_vals.corr()
numeric_corr.sort_values(["Price"], ascending = False, inplace = True)
print(numeric_corr.Price)
# Out:
# Find most important features relative to Price-target
# Price                1.000000
# Power                0.777187
# Engine               0.696675
# Year                 0.227202
# Seats                0.046168
# Kilometers_Driven   -0.154463
# Name: Price, dtype: float64

# %%
plt.figure(figsize=(5,  3))
sns.heatmap(numeric_corr, annot=True, cmap='coolwarm', linewidth=0.5)
plt.title('Heatmap of Correlation')
plt.show()

# %%
df.head()
# Out:
#                 Cars Location  Year  Kilometers_Driven Fuel_Type Transmission  \
# 0         Honda Jazz  Chennai  2011              46000    Petrol       Manual
# 1      Toyota Innova   Mumbai  2016              36000    Diesel    Automatic
# 2        Maruti Ciaz    Kochi  2018              25692    Petrol       Manual
# 3  Mitsubishi Pajero    Delhi  2014             110000    Diesel       Manual
# 4              BMW 3    Kochi  2014              32982    Diesel    Automatic
#
#   Owner_Type  Engine   Power  Seats  Price
# 0      First    1199   88.70    5.0   4.50
# 1      First    2755  171.50    8.0  17.50
# 2      First    1462  103.25    5.0   9.95
# 3      First    2477  175.56    7.0  15.00
# 4      First    1995  190.00    5.0  18.55

# %%
xdf = df.groupby('Cars').agg({'Price': 'mean'})
xdf.head()
# Out:
#              Price
# Cars
# Audi A3  18.900000
# Audi A4  25.380000
# Audi A6  31.723333
# Audi Q3  27.126000
# Audi Q7  67.652500

# %%
ydf = df.groupby('Cars')['Price'].mean().index

# %%
df.groupby("Owner_Type")["Price"].mean()
# Out:
# Owner_Type
# First     13.823033
# Second    11.843818
# Third      1.983333
# Name: Price, dtype: float64

# %%
prod = [prod for prod, df in df.groupby('Cars')]
plt.figure(figsize=(25, 6))
plt.bar(ydf, xdf['Price']) ##
plt.xticks(prod, rotation='vertical')
plt.xlabel("Cars")
plt.ylabel("Price(in Lakhs)")
plt.show()

# %%
kilom = df.groupby('Cars').agg({'Kilometers_Driven': 'mean'})
fig, ax = plt.subplots(figsize=(20, 6))
ax1 = ax.twinx()
ax.bar(ydf, xdf['Price'])
ax1.plot(ydf, kilom, 'r-')
ax.set_xticklabels(ydf, rotation='vertical')
ax.set_yticklabels([0, '5L', '10L', '15L', '20L', '25L', '30L', '35L', '40L', '45L', '50L', '55L', '60L', '65L', '70L'])
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_32/1602042244.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ydf, rotation='vertical')
# /tmp/ipykernel_32/1602042244.py:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([0, '5L', '10L', '15L', '20L', '25L', '30L', '35L', '40L', '45L', '50L', '55L', '60L', '65L', '70L'])

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(data=df, x='Engine', y='Price', hue='Transmission')
plt.xlabel('Engine')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(data=df, x='Power', y='Price', hue='Fuel_Type')
plt.xlabel('Power')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# ## Building a Machine Learning Model

# %%
import copy
data_train = copy.copy(df)
data_test = copy.copy(testdf)

dfcols = np.array(df.columns[df.dtypes != object])
for i in data_train.columns:
    if i not in dfcols:
        data_train[i] = data_train[i].map(str)
        data_test[i] = data_test[i].map(str)
data_train.drop(columns = dfcols, inplace=True)
data_test.drop(columns=np.delete(dfcols, len(dfcols)-1), inplace=True)

# %%
#Lable Encoding the data
from sklearn.preprocessing import LabelEncoder
from collections import defaultdict

dfcols = np.array(df.columns[df.dtypes != object])
d = defaultdict(LabelEncoder)

data_train = data_train.apply(lambda x: d[x.name].fit_transform(x))
data_test = data_test.apply(lambda x: d[x.name].fit_transform(x))
data_train[dfcols] = df[dfcols]
data_test[np.delete(dfcols,len(dfcols)-1)]=testdf[np.delete(dfcols,len(dfcols)-1)]

# %%
data_train.head()
# Out:
#    Cars  Location  Fuel_Type  Transmission  Owner_Type  Year  \
# 0    27         2          2             1           0  2011
# 1    98         9          1             0           0  2016
# 2    55         7          2             1           0  2018
# 3    77         4          1             1           0  2014
# 4     6         7          1             0           0  2014
#
#    Kilometers_Driven  Engine   Power  Seats  Price
# 0              46000    1199   88.70    5.0   4.50
# 1              36000    2755  171.50    8.0  17.50
# 2              25692    1462  103.25    5.0   9.95
# 3             110000    2477  175.56    7.0  15.00
# 4              32982    1995  190.00    5.0  18.55

# %%
data_test.head()
# Out:
#    Cars  Location  Fuel_Type  Transmission  Owner_Type  Year  \
# 0    67         9          1             1           0  2017
# 1    65         2          1             1           1  2014
# 2    59         9          2             0           0  2017
# 3     4         9          1             0           0  2012
# 4    59         6          2             1           0  2018
#
#    Kilometers_Driven  Engine   Power  Seats
# 0              34000    2393  147.80    7.0
# 1              70000    1364   67.06    5.0
# 2              13500    1598  103.52    5.0
# 3              66889    1995  190.00    5.0
# 4               4000    1598  103.52    5.0

# %%
#The data which has to be trained
charac_train = ['Cars', 'Location', 'Fuel_Type', 'Transmission', 'Owner_Type', 'Year', 'Kilometers_Driven', 'Engine', 'Power', 'Seats']

X = data_train[charac_train].values
y = data_train['Price'].values

# %%
#Splitting the data into training and testing
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBClassifier
from xgboost.sklearn import XGBRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn import metrics
import math
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=25)

# %%
#Comparing accuracy of models which we could have used
regressors = [
    ['MultiLinearRegressor', LinearRegression()],
    ['DecisionTreeRegressor', DecisionTreeRegressor()],
    ['RandomForestRegressor', RandomForestRegressor()],
    ['GradientBoostingRegressor', GradientBoostingRegressor()],
    ['XGBRegressor', XGBRegressor()]
]

resultsacc1 = []
resultsacc2 = []

for model in regressors:
    name = model[0]
    mod = model[1]
    
    mod.fit(X_train, y_train)
    y_pred = mod.predict(X_test)
    
    #Errors Metrics
    mse = metrics.mean_squared_error(y_pred,y_test)
    rmse = math.sqrt(mse)
    mae = metrics.mean_absolute_error(y_pred,y_test)
    
    #Accuracy Metrics
    RMSE = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
    acctrs = mod.score(X_train, y_train)
    acctes = mod.score(X_test, y_test)
    
    resultsacc1.append({'Model': name, 'MeanAbsoluteError': mae, 'AccuracyTraining': acctrs, 'AccuracyTesting': acctes})
    resultsacc2.append({'Model': name, 'MeanSqauredError': mse, 'RootMeanSquareError': rmse, 'MeanAbsoluteError': mae})
    
results1_df = pd.DataFrame(resultsacc1)
results2_df = pd.DataFrame(resultsacc2)


print(results1_df)
print(results2_df)
# Out:
#                        Model  MeanAbsoluteError  AccuracyTraining  \
# 0       MultiLinearRegressor           4.616490          0.695677
# 1      DecisionTreeRegressor           2.680364          1.000000
# 2      RandomForestRegressor           2.207085          0.971121
# 3  GradientBoostingRegressor           2.180207          0.975332
# 4               XGBRegressor           1.978270          0.999924
#
#    AccuracyTesting
# 0         0.651331
# 1         0.726826
# 2         0.801487
# 3         0.834386
# 4         0.830842
#                        Model  MeanSqauredError  RootMeanSquareError  \
# 0       MultiLinearRegressor         59.365513             7.704902
# 1      DecisionTreeRegressor         46.511466             6.819932
# 2      RandomForestRegressor         33.799441             5.813729
# 3  GradientBoostingRegressor         28.198017             5.310181
# 4               XGBRegressor         28.801327             5.366687
#
#    MeanAbsoluteError
# 0           4.616490
# 1           2.680364
# 2           2.207085
# 3           2.180207
# 4           1.978270

# %%
# The above comparision makes the inference that XGBRegressor is more accurate in training and testing.
model = XGBRegressor(n_estimators=1000)

# %%
#model predict
model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=1000, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
y_pred = model.predict(X_test)

# %%
#MSE, RMSE, MAE
import math
mse = metrics.mean_squared_error(y_pred,y_test)
rmse = math.sqrt(mse)
mae = metrics.mean_absolute_error(y_pred,y_test)
vals = {
    'Type of Error': ['Mean Squared Error', 'Root Mean Squared Error', 'Mean Absolute Error'],
    'Value of Error': [mse, rmse, mae]
}
pd.DataFrame(vals)
# Out:
#              Type of Error  Value of Error
# 0       Mean Squared Error       28.864980
# 1  Root Mean Squared Error        5.372614
# 2      Mean Absolute Error        1.983031

# %%
model.predict([[2, 2, 2003, 10000, 0, 1, 0, 2000, 100, 3]])
# Out:
# array([8.19505], dtype=float32)

# %%
true_color = 'b'  # Blue
pred_color = 'r'  # Red

plt.scatter(y_test, y_test, color=true_color, label='True Values')
plt.scatter(y_test, y_pred, color=pred_color, label='Predicted Values')
plt.xlabel("True Values (y_test)")
plt.ylabel("Predicted Values (y_pred)")
plt.title("True vs. Predicted Values (Regression)")

# Create a legend to label the points
plt.legend()
plt.show()
